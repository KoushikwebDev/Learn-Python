# %% [markdown]
# <a href="https://colab.research.google.com/github/KoushikwebDev/Learn-Python/blob/master/python_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python basics

# %%
def chai():
  print("hello")
  print("hello")
  print("hello")
chai()
# Out:
# hello
# hello
# hello
